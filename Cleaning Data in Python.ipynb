# %%
import os
import sys
import numpy as np
import pandas as pd

# %%
path = (r"C:\Users\Jwpel\Downloads")
input_data = "\mod1_assessment_data.csv"
df = pd.read_csv(filepath_or_buffer=(r"C:\Users\Jwpel\Downloads\mod1_assessment_data.csv") 
                                     ,sep=",", encoding="latin1")
df.head(10)
# Out:
#    year   month carrier            carrier_name airport  \
# 0  2016       3      AA  American Airlines Inc.     JFK
# 1  2016       3      OO   SkyWest Airlines Inc.     FNT
# 2  2016       3      OO   SkyWest Airlines Inc.     FWA
# 3  2016       3      OO   SkyWest Airlines Inc.     COS
# 4  2016       3      OO   SkyWest Airlines Inc.     SAT
# 5  2016       3      OO   SkyWest Airlines Inc.     HLN
# 6  2016       3      OO   SkyWest Airlines Inc.     BHM
# 7  2016       3      OO   SkyWest Airlines Inc.     TVC
# 8  2016       3      OO   SkyWest Airlines Inc.     CMH
# 9  2016       3      OO   SkyWest Airlines Inc.     PIT
#
#                                         airport_name  arr_flights  arr_del15  \
# 0        New York, NY: John F. Kennedy International       1605.0      354.0
# 1                    Flint, MI: Bishop International         53.0        2.0
# 2           Fort Wayne, IN: Fort Wayne International        355.0       67.0
# ...

# %%
df_copy = df

# %%
df_copy.duplicated().sum()
# Out:
# 0

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 974     False
# 975     False
# 976     False
# 977     False
# 978     False
# 979     False
# 980     False
# 981     False
# 982     False
# 983     False
# 984     False
# 985     False
# 986     False
# 987     False
# 988     False
# 989     False
# 990     False
# 991     False
# 992     False
# 993     False
# 994     False
# 995     False
# 996     False
# 997     False
# 998     False
# 999     False
# 1000    False
# 1001    False
# 1002    False
# 1003    False
# ...

# %%
df_copy["arr_del15"].fillna(df_copy["arr_del15"].mean(), inplace = True)

# %%
df_copy["carrier_ct"].fillna(df_copy["carrier_ct"].mean(), inplace = True)

# %%
df_copy["nas_ct"].fillna(df_copy["nas_ct"].median(), inplace = True)

# %%
df_copy["weather_delay"].fillna(df_copy["weather_delay"].median(), inplace = True)

# %%
df_copy["nas_delay"].fillna(df_copy["nas_delay"].median(), inplace = True)

# %%
df_copy["late_aircraft_ct"].fillna(0, inplace = True)

# %%
df_copy["arr_cancelled"].fillna(0, inplace = True)

# %%
df_copy["arr_diverted"].fillna(0, inplace = True)

# %%
df_copy["security_delay"].fillna(3, inplace = True)

# %%
df_copy.drop('year', axis=1, inplace=True)

# %%
df_copy.drop(df_copy.columns[[0]], axis = 1, inplace=True)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004 entries, 0 to 1003
# Data columns (total 20 columns):
# carrier                1004 non-null object
# carrier_name           1004 non-null object
# airport                1004 non-null object
# airport_name           1004 non-null object
# arr_flights            1004 non-null float64
# arr_del15              1004 non-null float64
# carrier_ct             1004 non-null float64
#  weather_ct            1003 non-null float64
# nas_ct                 1004 non-null float64
# security_ct            1003 non-null float64
# late_aircraft_ct       1004 non-null float64
# arr_cancelled          1004 non-null float64
# arr_diverted           1004 non-null float64
#  arr_delay             1003 non-null float64
#  carrier_delay         1003 non-null float64
# weather_delay          1004 non-null float64
# nas_delay              1004 non-null float64
# security_delay         1004 non-null float64
# ...

# %%
df_copy.rename(columns = {' arr_delay':'arr_delay', ' carrier_delay':'carrier_delay', ' weather_ct':'weather_ct'}, inplace = True)

# %%
df_copy['arr_delay'].fillna(df_copy['arr_delay'].mean, inplace = True)

# %%
df_copy['carrier_delay'].fillna(df_copy['carrier_delay'].mean, inplace = True)

# %%
df_copy['weather_ct'].fillna(df_copy['weather_ct'].median, inplace = True)

# %%
file = "output_data.csv"
df_copy.to_csv(os.path.join(path, file), sep=",", encoding = "latin1", index = False)
print("LOCATION" + path)
print("FILENAME" + file)
print()
# Out:
# LOCATIONC:\Users\Jwpel\Downloads
# FILENAMEoutput_data.csv

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004 entries, 0 to 1003
# Data columns (total 20 columns):
# carrier                1004 non-null object
# carrier_name           1004 non-null object
# airport                1004 non-null object
# airport_name           1004 non-null object
# arr_flights            1004 non-null float64
# arr_del15              1004 non-null float64
# carrier_ct             1004 non-null float64
# weather_ct             1004 non-null object
# nas_ct                 1004 non-null float64
# security_ct            1003 non-null float64
# late_aircraft_ct       1004 non-null float64
# arr_cancelled          1004 non-null float64
# arr_diverted           1004 non-null float64
# arr_delay              1004 non-null object
# carrier_delay          1004 non-null object
# weather_delay          1004 non-null float64
# nas_delay              1004 non-null float64
# security_delay         1004 non-null float64
# late_aircraft_delay    1004 non-null float64
# ...

# %%
df_copy.head(5)
# Out:
#   carrier            carrier_name airport  \
# 0      AA  American Airlines Inc.     JFK
# 1      OO   SkyWest Airlines Inc.     FNT
# 2      OO   SkyWest Airlines Inc.     FWA
# 3      OO   SkyWest Airlines Inc.     COS
# 4      OO   SkyWest Airlines Inc.     SAT
#
#                                         airport_name  arr_flights  arr_del15  \
# 0        New York, NY: John F. Kennedy International       1605.0      354.0
# 1                    Flint, MI: Bishop International         53.0        2.0
# 2           Fort Wayne, IN: Fort Wayne International        355.0       67.0
# 3  Colorado Springs, CO: City of Colorado Springs...        477.0      108.0
# 4         San Antonio, TX: San Antonio International        156.0       35.0
#
#    carrier_ct weather_ct  nas_ct  security_ct  late_aircraft_ct  \
# 0       84.10        6.6  161.41         2.71             99.18
# 1        0.00          0    2.00         0.00              0.00
# ...
